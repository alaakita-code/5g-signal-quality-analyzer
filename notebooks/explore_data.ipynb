# %% [markdown]
# # 探索性分析:5G/4G 訊號品質模擬資料
#
# 本 Notebook 用於快速檢視模擬資料的分佈與初步統計,
# 作為正式分析模組(`src/analysis/`)開發前的探索步驟。

# %%
import sys
from pathlib import Path

import pandas as pd
import yaml

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from data_generator.simulate_cell_data import generate

with open(PROJECT_ROOT / "configs" / "default_config.yaml", encoding="utf-8") as f:
    config = yaml.safe_load(f)

df = generate(config)
df.head()

# %%
df[["rsrp_dbm", "rsrq_db", "sinr_db", "load_pct"]].describe()

# %%
df.groupby("cell_id")[["rsrp_dbm", "sinr_db", "load_pct"]].mean().sort_values("load_pct", ascending=False)
